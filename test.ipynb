# %%
import pandas as pd

# %%
df = pd.read_excel('data/data.xlsx')

# %%
df
# Out:
#               Unnamed: 0  ดัชนีการลงทุนภาคเอกชน  X1 หนี้รัฐบาล  \
# 0    2556-01-01 00:00:00                  121.9     3531418.63
# 1    2556-02-01 00:00:00                  118.9     3555634.61
# 2    2556-03-01 00:00:00                  131.8     3563398.53
# 3    2556-04-01 00:00:00                  117.2     3589728.39
# 4    2556-05-01 00:00:00                  126.5     3609170.92
# ..                   ...                    ...            ...
# 127  2566-08-01 00:00:00                  132.7     9676757.05
# 128  2566-09-01 00:00:00                  130.1     9779786.75
# 129  2566-10-01 00:00:00                  143.9     9779797.23
# 130  2566-11-01 00:00:00                  156.2     9780061.01
# 131  2566-12-01 00:00:00                  140.4     9726709.15
#
#      X2 หนี้รัฐวิสาหกิจ  \
# 0            1066503.28
# 1            1072414.05
# 2            1069302.32
# 3            1060180.28
# 4            1065687.08
# ..                  ...
# 127          1075590.65
# ...
